# %%
import pickle
import pandas as pd
import numpy as np

# %% [markdown]
# Contains EDA + Baseline (Task2)

# %% [markdown]
# * *players* содержит ФИО игроков;
# * *results.keys() == tournaments.keys()* — т.е. по каждому турниру есть рез-тат в соответствующей таблице;
# * по турнирам есть *questionQty* — число вопросов в раунде и *type* — тип сор-я (Синхрон/Асинхрон и тд)

# %% [markdown]
# ### EDA + Preproc

# %%
with open('tournaments.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data = pd.DataFrame(data).T

# %%
data = data[data['dateStart'] >= '2019']

# %%
print(data.shape)
data.head()
# Out:
# (1109, 9)
#         id                                   name                  dateStart  \
# 4628  4628                             Семь сорок  2020-12-30T16:00:00+03:00
# 4772  4772  Синхрон северных стран. Зимний выпуск  2019-01-05T19:00:00+03:00
# 4957  4957                     Синхрон Биркиркары  2020-02-21T00:00:00+03:00
# 4973  4973               Балтийский Берег. 3 игра  2019-01-25T19:05:00+03:00
# 4974  4974               Балтийский Берег. 4 игра  2019-03-01T19:05:00+03:00
#
#                         dateEnd                          type       season  \
# 4628  2020-12-30T16:00:00+03:00  {'id': 3, 'name': 'Синхрон'}         None
# 4772  2019-01-09T19:00:00+03:00  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 4957  2020-02-27T23:00:00+03:00  {'id': 3, 'name': 'Синхрон'}  /seasons/53
# 4973  2019-01-29T19:00:00+03:00  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 4974  2019-03-05T19:00:00+03:00  {'id': 3, 'name': 'Синхрон'}  /seasons/52
#
# ...

# %%
data['season'].value_counts()
# Out:
# /seasons/53    596
# /seasons/52    419
# Name: season, dtype: int64

# %%
data.type.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'dict'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'dict'
# {'id': 3, 'name': 'Синхрон'}              556
# {'id': 2, 'name': 'Обычный'}              425
# {'id': 8, 'name': 'Асинхрон'}             109
# {'id': 5, 'name': 'Общий зачёт'}           12
# {'id': 6, 'name': 'Строго синхронный'}      7
# Name: type, dtype: int64

# %%
with open('results.pkl', 'rb') as f:
    res = pickle.load(f)

# %%
data.id
# Out:
# 4628    4628
# 4772    4772
# 4957    4957
# 4973    4973
# 4974    4974
#         ...
# 6481    6481
# 6482    6482
# 6483    6483
# 6484    6484
# 6485    6485
# Name: id, Length: 1109, dtype: object

# %%
res_df = pd.DataFrame(res[4772])

# %%
res_df.columns
# Out:
# Index(['team', 'mask', 'current', 'questionsTotal', 'synchRequest', 'position',
#        'controversials', 'flags', 'teamMembers'],
#       dtype='object')

# %%
res_df.head(3)
# Out:
#                                                 team  \
# 0  {'id': 45556, 'name': 'Рабочее название', 'tow...
# 1  {'id': 1030, 'name': 'Сборная Бутана', 'town':...
# 2  {'id': 4252, 'name': 'Ять', 'town': {'id': 197...
#
#                                    mask  \
# 0  111111111011111110111111111100010010
# 1  111111111011110100101111011001011010
# 2  111111111011110101101111001011110000
#
#                                              current  questionsTotal  \
# 0  {'name': 'Рабочее название', 'town': {'id': 28...              28
# 1  {'name': 'Сборная Бутана', 'town': {'id': 346,...              25
# 2  {'name': 'Ять', 'town': {'id': 197, 'name': 'М...              25
#
#                                         synchRequest  position  \
# 0  {'id': 56392, 'venue': {'id': 3030, 'name': 'С...       1.0
# 1  {'id': 56690, 'venue': {'id': 3151, 'name': 'У...       5.5
# 2  {'id': 56814, 'venue': {'id': 3112, 'name': 'М...       5.5
#
# ...

# %%
def is_good(tournament):
    flg = True
    for team in tournament:
        if (team['teamMembers'] == []) or (team.get('mask') is None):
            flg = False
    return flg

# %%
with open('results.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
4628 in data.id.unique()
# Out:
# True

# %%
results_corrected  = {i : results[i] for i in results.keys() if is_good(results[i])}

# %%
len(results_corrected)
# Out:
# 3743

# %%
data.head()
# Out:
#         id                                   name                  dateStart  \
# 4628  4628                             Семь сорок  2020-12-30T16:00:00+03:00
# 4772  4772  Синхрон северных стран. Зимний выпуск  2019-01-05T19:00:00+03:00
# 4957  4957                     Синхрон Биркиркары  2020-02-21T00:00:00+03:00
# 4973  4973               Балтийский Берег. 3 игра  2019-01-25T19:05:00+03:00
# 4974  4974               Балтийский Берег. 4 игра  2019-03-01T19:05:00+03:00
#
#                         dateEnd                          type       season  \
# 4628  2020-12-30T16:00:00+03:00  {'id': 3, 'name': 'Синхрон'}         None
# 4772  2019-01-09T19:00:00+03:00  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 4957  2020-02-27T23:00:00+03:00  {'id': 3, 'name': 'Синхрон'}  /seasons/53
# 4973  2019-01-29T19:00:00+03:00  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 4974  2019-03-05T19:00:00+03:00  {'id': 3, 'name': 'Синхрон'}  /seasons/52
#
# ...

# %%
data.id.unique()
# Out:
# array([4628, 4772, 4957, ..., 6483, 6484, 6485], dtype=object)

# %%
results2  = {i : results_corrected[i] for i in results_corrected.keys() if i in data.id.unique()}

# %%
len(results2)
# Out:
# 1047

# %%
# results2[4772]

# %%
# results2[5310]

# %%
# results2.keys()

# %% [markdown]
# ### Baseline model
# **Выбираем**
# * повопросные результаты команды просто относятся к каждому из её игроков;
# * повопросные результаты — это фактически результаты броска монетки, и их предсказание имеет отношение к бинарной классификации;
# * в разных турнирах вопросы совсем разного уровня сложности, поэтому модель должна это учитывать; скорее всего, модель должна будет явно обучать не только силу каждого игрока, но и сложность каждого вопроса;

# %%
results2[4772]
# Out:
# [{'team': {'id': 45556,
#    'name': 'Рабочее название',
#    'town': {'id': 285, 'name': 'Санкт-Петербург'}},
#   'mask': '111111111011111110111111111100010010',
#   'current': {'name': 'Рабочее название',
#    'town': {'id': 285, 'name': 'Санкт-Петербург'}},
#   'questionsTotal': 28,
#   'synchRequest': {'id': 56392,
#    'venue': {'id': 3030, 'name': 'Санкт-Петербург'}},
#   'position': 1,
#   'controversials': [{'id': 91169,
#     'questionNumber': 15,
#     'answer': 'Мьёльнир',
#     'issuedAt': '2019-01-06T13:28:48+03:00',
#     'status': 'A',
#     'comment': '',
#     'resolvedAt': '2019-01-06T15:25:54+03:00',
#     'appealJuryComment': None}],
#   'flags': [],
#   'teamMembers': [{'flag': 'Б',
#     'usedRating': 13507,
#     'rating': 13507,
#     'player': {'id': 6212,
#      'name': 'Юрий',
#      'patronymic': 'Яковлевич',
#      'surname': 'Выменец'}},
#    {'flag': 'Б',
#     'usedRating': 10988,
#     'rating': 13185,
#     'player': {'id': 18332,
# ...

# %%
item["team"]#["id"]["name"]
# item[""]
# Out:
# {'id': 68319, 'name': 'Альфа-самцы', 'town': {'id': 201, 'name': 'Москва'}}

# %% [markdown]
# В данном подходе на каждую команду (== игрока) есть пул вопросов с результатом (0/1) и веса: сложность соревнования и сложность вопроса

# %%
# for key in results2.keys():
#     print(key, '\n')

# %%
len(results2.keys())
# Out:
# 1047

# %%
from tqdm import tqdm

# %%
def get_arr(string):
    out = []
    for i in range(len(string)):
        try: 
            out.append(int(string[i]))
        except:
            out.append(0)
    return out

# %%
df = pd.DataFrame(columns = ['tournament_key', 'team_id', 'team_name', 'mask', 'questionsTotal', 'position', 'teamMembers'])
df_w = pd.DataFrame(columns = ['tournament_key', 'weights_arr'])

i = 0
for key in tqdm(results2.keys()):
    df_tmp = pd.DataFrame(columns = ['tournament_key','team_id', 'team_name', 'mask', 'questionsTotal', 'position', 'teamMembers'])
    for item in results2[key]:
        df_tmp = df_tmp.append({
                        'tournament_key' : key,
                        'team_id' : item["team"]["id"], 
                        'team_name' : item["team"]["name"],
                        'mask': item["mask"] , 
                        'questionsTotal' : item["questionsTotal"], 
                        'position' : item["position"], 
                        'teamMembers' : item["teamMembers"]
                       }, ignore_index=True)

    arr = np.array(df_tmp['mask'].apply(get_arr).values.tolist())
#     print(arr.shape)
    df = df.append(df_tmp)
    try: 
        weights = np.mean(arr, axis=0)
    except:
        weights = [-1]
    df_w = df_w.append({'tournament_key' : key, 'weights_arr' : weights}, ignore_index=True)
    
    i+=1
    
    if i == 10:
        break;

# %%
# for k in range(0,10):
#     print(k, len(df_w[k:k+1]['weights_arr'][k]))

# %%
df_w.to_csv('bs1_weights.csv', header=True, index=False)
df.to_csv('bs1_data.csv', header=True, index=False)

# %%
sum(df_w['weights_arr'].isna())
# Out:
# 233

# %%
df.head()
# Out:
#   tournament_key team_id         team_name  \
# 0           4772   45556  Рабочее название
# 1           4772    1030    Сборная Бутана
# 2           4772    4252               Ять
# 3           4772    5444             Эйфью
# 4           4772   40931     Здоровенный Я
#
#                                    mask questionsTotal position  \
# 0  111111111011111110111111111100010010             28        1
# 1  111111111011110100101111011001011010             25      5.5
# 2  111111111011110101101111001011110000             25      5.5
# 3  101111101111111110001101011001111010             25      5.5
# 4  111111101011111101000111001001111110             25      5.5
#
#                                          teamMembers
# 0  [{'flag': 'Б', 'usedRating': 13507, 'rating': ...
# 1  [{'flag': None, 'usedRating': 13058, 'rating':...
# 2  [{'flag': 'К', 'usedRating': 9584, 'rating': 9...
# 3  [{'flag': 'Л', 'usedRating': 8592, 'rating': 8...
# ...

# %% [markdown]
# Под каждую команду строим свою модель team_name == id:
#
# <center> mask[i]~ $w_1$*df_w.weights_arr + $w_0$ </center>
#
# PS Прибавка $w_2$*data.type не дала лучший результат

# %%
df_w = pd.read_csv('bs1_weights.csv')

df_w['weights_arr'] = df_w['weights_arr'].fillna('[0]')
df_w['weights_arr'] = df_w['weights_arr'].apply(lambda x: x.replace('\n', '')[1:-1].split())

arr = []
for i in range(df_w.shape[0]):
    val = len(df_w[i:i+1]['weights_arr'][i])
    arr.append(val)
df_w['len'] = pd.Series(arr)

df_w['tournament_key'] = df_w['tournament_key'].astype(int)

df_w.head()
# Out:
#    tournament_key                                        weights_arr  len
# 0            4628                                                [0]    1
# 1            4772  [0.88311688, 0.77922078, 0.44588745, 0.5194805...   36
# 2            4957  [0.2826087, 0.11956522, 0.85869565, 0.57608696...   39
# 3            4973  [0.56183057, 0.80331061, 0.77312561, 0.5394352...   36
# 4            4974  [0.3164557, 0.48880234, 0.55890944, 0.57935735...   36

# %%
df = pd.read_csv('bs1_data.csv')

# %%
df.shape
# Out:
# (92072, 7)

# %%
#data = data[['id', 'name', 'dateStart', 'questionQty']]

# %%
#data.columns = ['tournament_key', 'tournament_name', 'date', 'questionQty']

# %%
#data.to_csv('bs1_tourn.csv', header=True, index=False)

# %%
data = pd.read_csv('bs1_tourn.csv')

# %%
print(df[df['team_id'] == 45556].shape[0])
df[df['team_id'] == 45556].head()
# Out:
# 52
#       tournament_key  team_id         team_name  \
# 0               4772    45556  Рабочее название
# 323             4973    45556  Рабочее название
# 1363            4974    45556  Рабочее название
# 2378            4975    45556  Рабочее название
# 5872            5025    45556  Рабочее название
#
#                                                   mask  questionsTotal  \
# 0                 111111111011111110111111111100010010              28
# 323               111111111111111011110101110111111111              32
# 1363              011111111111111111111011111001111111              32
# 2378              111101011111101011111111100110111111              29
# 5872  101111111111111111011111100000100000000011010010              28
#
#       position                                        teamMembers
# 0          1.0  [{'flag': 'Б', 'usedRating': 13507, 'rating': ...
# 323        1.5  [{'flag': 'Б', 'usedRating': 13600, 'rating': ...
# ...

# %%
df_sample = df[df['team_id'] == 45556].merge(df_w, on='tournament_key')

# %%
# question + weight
# len(df_sample[0:1]['mask'][0]), len(df_sample[0:1]['weights_arr'][0])
df_sample['mask'][0][0], df_sample['weights_arr'].array[0][0]
# Out:
# ('1', '0.88311688')

# %%
df_sample['mask'] = df_sample['mask'].apply(lambda x: list(map(int, str(x).replace('X', '0').replace('?', '0'))))

# %%
def explode(df, lst_cols, fill_value='', preserve_index=False):
    # make sure `lst_cols` is list-alike
    if (lst_cols is not None
        and len(lst_cols) > 0
        and not isinstance(lst_cols, (list, tuple, np.ndarray, pd.Series))):
        lst_cols = [lst_cols]
    # all columns except `lst_cols`
    idx_cols = df.columns.difference(lst_cols)
    # calculate lengths of lists
    lens = df[lst_cols[0]].str.len()
    # preserve original index values    
    idx = np.repeat(df.index.values, lens)
    # create "exploded" DF
    res = (pd.DataFrame({
                col:np.repeat(df[col].values, lens)
                for col in idx_cols},
                index=idx)
             .assign(**{col:np.concatenate(df.loc[lens>0, col].values)
                            for col in lst_cols}))
    # append those rows that have empty lists
    if (lens == 0).any():
        # at least one list in cells is empty
        res = (res.append(df.loc[lens==0, idx_cols], sort=False)
                  .fillna(fill_value))
    # revert the original index order
    res = res.sort_index()
    # reset index if requested
    if not preserve_index:        
        res = res.reset_index(drop=True)
    return res

# %%
# for i in range(df_sample.shape[0]):
#     print(i, len(df_sample[i:i+1]['mask'][i]), len(df_sample[i:i+1]['weights_arr'][i]))

# %%
# df_sample[df_sample['len'] > 1]

# %%
df_team = explode(df_sample[df_sample['len'] > 1], ['mask', 'weights_arr'], fill_value='')

# %%
df_team[['team_id', 'tournament_key', 'mask', 'weights_arr']]
# Out:
#       team_id  tournament_key  mask weights_arr
# 0       45556            4772     1  0.88311688
# 1       45556            4772     1  0.77922078
# 2       45556            4772     1  0.44588745
# 3       45556            4772     1  0.51948052
# 4       45556            4772     1  0.87878788
# ...       ...             ...   ...         ...
# 2107    45556            6284     1   0.3255814
# 2108    45556            6284     1  0.19767442
# 2109    45556            6284     1  0.36046512
# 2110    45556            6284     1  0.55813953
# 2111    45556            6284     0  0.06976744
#
# [2112 rows x 4 columns]

# %%
df_team = df_team[['team_id', 'tournament_key', 'mask', 'weights_arr']]\
            .merge(data[['tournament_key', 'date']], on='tournament_key')

# %%
df_team
# Out:
#       team_id  tournament_key  mask weights_arr                       date
# 0       45556            4772     1  0.88311688  2019-01-05T19:00:00+03:00
# 1       45556            4772     1  0.77922078  2019-01-05T19:00:00+03:00
# 2       45556            4772     1  0.44588745  2019-01-05T19:00:00+03:00
# 3       45556            4772     1  0.51948052  2019-01-05T19:00:00+03:00
# 4       45556            4772     1  0.87878788  2019-01-05T19:00:00+03:00
# ...       ...             ...   ...         ...                        ...
# 2107    45556            6284     1   0.3255814  2020-02-21T00:00:00+03:00
# 2108    45556            6284     1  0.19767442  2020-02-21T00:00:00+03:00
# 2109    45556            6284     1  0.36046512  2020-02-21T00:00:00+03:00
# 2110    45556            6284     1  0.55813953  2020-02-21T00:00:00+03:00
# 2111    45556            6284     0  0.06976744  2020-02-21T00:00:00+03:00
#
# [2112 rows x 5 columns]

# %%
df_team[df_team['date'] < '2020'].shape[0] + df_team[df_team['date'] >= '2020'].shape[0]
# Out:
# 2112

# %%
train = df_team[df_team['date'] < '2020']
test = df_team[df_team['date'] >= '2020']

# %%
from sklearn.linear_model import LinearRegression

# %%
train['weights_arr'].values.shape, train['mask'].values.shape
# Out:
# ((1728,), (1728,))

# %%
lr = LinearRegression()
lr.fit(train['weights_arr'].values.reshape(-1, 1), train['mask'].values)
print("Alpha = %.4f, Beta = %.4f" % (lr.coef_[0], lr.intercept_))
# Out:
# Alpha = 0.7852, Beta = 0.3991

# %%
len(df['team_id'].unique())
# Out:
# 12099

# %%
np.mean(res)
# Out:
# 78.1445184089415

# %%
test['lr_pred'] = lr.predict(test['weights_arr'].values.reshape(-1, 1))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test['lr_pred_round'] = round(test['lr_pred'], 0).astype(int)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print('Всего ответов на вопросы в 2020  = %d' % test.shape[0])
print('Из них правильных ответов в 2020 = %d' % test[test['mask'] == test['lr_pred_round']].shape[0])
test[['mask', 'lr_pred_round']].head()
# Out:
# Всего ответов на вопросы в 2020  = 384
# Из них правильных ответов в 2020 = 314
#       mask  lr_pred_round
# 1118     1              1
# 1119     1              1
# 1120     0              0
# 1121     1              1
# 1122     0              1

# %%
teams = df['team_id'].unique()
# teams = [45556,  1030,  4252]

res = []
for team_id in tqdm(teams):
    df_sample = pd.DataFrame(); df_team = pd.DataFrame(); 
    train_team = pd.DataFrame(); test_team = pd.DataFrame(); 
    #join questions level (avg)
    df_sample = df[df['team_id'] == team_id].merge(df_w, on='tournament_key')
    
    #transform data
    df_sample['mask'] = df_sample['mask'].apply(lambda x: list(map(int, str(x).replace('X', '0').replace('?', '0'))))
    df_team = explode(df_sample[df_sample['len'] > 1], ['mask', 'weights_arr'], fill_value='')
    df_team = df_team[['team_id', 'tournament_key', 'mask', 'weights_arr']]\
                .merge(data[['tournament_key', 'date']], on='tournament_key')
    
    #train-test
    train_team = df_team[df_team['date'] < '2020']
    test_team = df_team[df_team['date'] >= '2020']
    
    if test_team.shape[0] != 0 and train_team.shape[0] != 0:
        
        lr = LinearRegression()
        lr.fit(train_team['weights_arr'].values.reshape(-1, 1), train_team['mask'].values)
        #lr2.fit(train[['nday', 'nday_squared']].values, train['new_cases_log'].values)

        test_team['lr_pred'] = lr.predict(test_team['weights_arr'].values.reshape(-1, 1))
        test_team['lr_pred_round'] = round(test_team['lr_pred'], 0).astype(int)


        num_q = test_team.shape[0]
        right_fit = test_team[test_team['mask'] == test_team['lr_pred_round']].shape[0]
    #     print('Название команды:', team_id)
    #     print('Всего ответов на вопросы в 2020 = %d' % num_q)
    #     print('Где верно предсказанных ответов = %d (%.2f)' % (right_fit, 100*right_fit/num_q))
        res.append(100*right_fit/num_q)
# Out:
#   0%|          | 0/12099 [00:00<?, ?it/s]/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
print('Accuracy повопросный = %.4f' % np.mean(res))
# Out:
# Accuracy повопросный = 75.8912
